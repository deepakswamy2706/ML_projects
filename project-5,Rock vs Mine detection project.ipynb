# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\user\\saurabh sir pandas\\Final Projects\\Copy of sonar data.csv')

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
df['R'].value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %% [markdown]
# # here values for mines are 111 and for rock are 96 so its not a proper one sided data

# %%
df.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22524\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# 0.0200  1.000000  0.736104  0.571706  0.490853  0.345744  0.238824  0.262095
# 0.0371  0.736104  1.000000  0.779915  0.607297  0.419877  0.332319  0.279328
# 0.0428  0.571706  0.779915  1.000000  0.782662  0.546365  0.346271  0.190628
# 0.0207  0.490853  0.607297  0.782662  1.000000  0.729338  0.352901  0.248713
# 0.0954  0.345744  0.419877  0.546365  0.729338  1.000000  0.597438  0.334831
# 0.0986  0.238824  0.332319  0.346271  0.352901  0.597438  1.000000  0.703624
# 0.1539  0.262095  0.279328  0.190628  0.248713  0.334831  0.703624  1.000000
# ...

# %%
(df.isnull().sum()).value_counts()
# Out:
# 0    61
# dtype: int64

# %% [markdown]
# # no null values

# %%
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
sns.heatmap(df.corr())
plt.title('Correlation between columns ')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22524\2263672762.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %%
sns.countplot(x=df['R'])
plt.title('COUNTS OF ROCKS AND MINES')
# Out:
# Text(0.5, 1.0, 'COUNTS OF ROCKS AND MINES')

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(columns='R',axis=1)
y=df['R']

# %%
x
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Accuracy of model on test Data:',accuracy_score(y_test,y_pred))
# Out:
# Accuracy of model on test Data: 0.9285714285714286

# %%
input=(0.0414,0.0436,0.0447,0.0844,0.0419,0.1215,0.2002,0.1516,0.0818,0.1975,0.2309,0.3025,0.3938,0.5050,0.5872,0.6610,0.7417,0.8006,0.8456,0.7939,0.8804,0.8384,0.7852,0.8479,0.7434,0.6433,0.5514,0.3519,0.3168,0.3346,0.2056,0.1032,0.3168,0.4040,0.4282,0.4538,0.3704,0.3741,0.3839,0.3494,0.4380,0.4265,0.2854,0.2808,0.2395,0.0369,0.0805,0.0541,0.0177,0.0065,0.0222,0.0045,0.0136,0.0113,0.0053,0.0165,0.0141,0.0077,0.0246,0.0198)
converted_input=np.array([[input]])
converted_input=converted_input.reshape(1,-1)
result=rfc.predict(converted_input)
result
if result=='R':
    print('the Object is Rock')
else:
    print('Alert!,Mine Ahead')
# Out:
# Alert!,Mine Ahead
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
