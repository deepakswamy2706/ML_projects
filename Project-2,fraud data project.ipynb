# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\user\\saurabh sir pandas\\Final Projects\\fraud.csv')

# %%
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
df.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15440\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     step    amount  oldbalanceOrg  newbalanceOrig  \
# step            1.000000  0.022373      -0.010058       -0.010299
# amount          0.022373  1.000000      -0.002762       -0.007861
# oldbalanceOrg  -0.010058 -0.002762       1.000000        0.998803
# newbalanceOrig -0.010299 -0.007861       0.998803        1.000000
# oldbalanceDest  0.027665  0.294137       0.066243        0.067812
# newbalanceDest  0.025888  0.459304       0.042029        0.041837
# isFraud         0.031578  0.076688       0.010154       -0.008148
# isFlaggedFraud  0.003277  0.012295       0.003835        0.003776
#
#                 oldbalanceDest  newbalanceDest   isFraud  isFlaggedFraud
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(sparse=False)

# %%
df['type']=ohe.fit_transform(df[['type']])
# Out:
# D:\anaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df
# Out:
#          step  type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1   0.0     9839.64  C1231006815      170136.00       160296.36
# 1           1   0.0     1864.28  C1666544295       21249.00        19384.72
# 2           1   0.0      181.00  C1305486145         181.00            0.00
# 3           1   0.0      181.00   C840083671         181.00            0.00
# 4           1   0.0    11668.14  C2048537720       41554.00        29885.86
# ...       ...   ...         ...          ...            ...             ...
# 6362615   743   0.0   339682.13   C786484425      339682.13            0.00
# 6362616   743   0.0  6311409.28  C1529008245     6311409.28            0.00
# 6362617   743   0.0  6311409.28  C1162922333     6311409.28            0.00
# 6362618   743   0.0   850002.52  C1685995037      850002.52            0.00
# 6362619   743   0.0   850002.52  C1280323807      850002.52            0.00
#
# ...

# %%
df['type'].value_counts()
# Out:
# 0.0    4963336
# 1.0    1399284
# Name: type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            float64
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 534.0+ MB

# %%
df['nameOrig']=df['nameOrig'].str.replace('C','')

# %%
df
# Out:
#          step  type      amount    nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1   0.0     9839.64  1231006815      170136.00       160296.36
# 1           1   0.0     1864.28  1666544295       21249.00        19384.72
# 2           1   0.0      181.00  1305486145         181.00            0.00
# 3           1   0.0      181.00   840083671         181.00            0.00
# 4           1   0.0    11668.14  2048537720       41554.00        29885.86
# ...       ...   ...         ...         ...            ...             ...
# 6362615   743   0.0   339682.13   786484425      339682.13            0.00
# 6362616   743   0.0  6311409.28  1529008245     6311409.28            0.00
# 6362617   743   0.0  6311409.28  1162922333     6311409.28            0.00
# 6362618   743   0.0   850002.52  1685995037      850002.52            0.00
# 6362619   743   0.0   850002.52  1280323807      850002.52            0.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            float64
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 534.0+ MB

# %%
df['nameOrig'].info
# Out:
# <bound method Series.info of 0          1231006815
# 1          1666544295
# 2          1305486145
# 3           840083671
# 4          2048537720
#               ...
# 6362615     786484425
# 6362616    1529008245
# 6362617    1162922333
# 6362618    1685995037
# 6362619    1280323807
# Name: nameOrig, Length: 6362620, dtype: object>

# %%
df['nameDest']=df['nameDest'].str.replace('C','')

# %%
df['nameDest']=df['nameDest'].str.replace('M','')

# %%
df['nameOrig']=df['nameOrig'].astype(int)

# %%
df['nameDest']=df['nameDest'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            float64
#  2   amount          float64
#  3   nameOrig        int32
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        int32
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(6), int32(2), int64(3)
# memory usage: 485.4 MB

# %%
df
# Out:
#          step  type      amount    nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1   0.0     9839.64  1231006815      170136.00       160296.36
# 1           1   0.0     1864.28  1666544295       21249.00        19384.72
# 2           1   0.0      181.00  1305486145         181.00            0.00
# 3           1   0.0      181.00   840083671         181.00            0.00
# 4           1   0.0    11668.14  2048537720       41554.00        29885.86
# ...       ...   ...         ...         ...            ...             ...
# 6362615   743   0.0   339682.13   786484425      339682.13            0.00
# 6362616   743   0.0  6311409.28  1529008245     6311409.28            0.00
# 6362617   743   0.0  6311409.28  1162922333     6311409.28            0.00
# 6362618   743   0.0   850002.52  1685995037      850002.52            0.00
# 6362619   743   0.0   850002.52  1280323807      850002.52            0.00
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=df.drop(columns='isFlaggedFraud',axis=1)

# %%
y=df['isFlaggedFraud']

# %%
x1=sc.fit_transform(x)

# %%
x1
# Out:
# array([[-1.70304158, -0.53096525, -0.28155992, ..., -0.3238139 ,
#         -0.33341141, -0.0359512 ],
#        [-1.70304158, -0.53096525, -0.29476726, ..., -0.3238139 ,
#         -0.33341141, -0.0359512 ],
#        [-1.70304158, -0.53096525, -0.2975548 , ..., -0.3238139 ,
#         -0.33341141, 27.8154828 ],
#        ...,
#        [ 3.51012348, -0.53096525, 10.1539526 , ..., -0.30366526,
#          1.403027  , 27.8154828 ],
#        [ 3.51012348, -0.53096525,  1.1097649 , ..., -0.3238139 ,
#         -0.33341141, 27.8154828 ],
#        [ 3.51012348, -0.53096525,  1.1097649 , ...,  1.59138312,
#          1.6698123 , 27.8154828 ]])

# %%
x1=pd.DataFrame(x1,columns=x.columns)

# %%
x1
# Out:
#              step      type     amount  nameOrig  oldbalanceOrg  \
# 0       -1.703042 -0.530965  -0.281560  0.253593      -0.229810
# 1       -1.703042 -0.530965  -0.294767  0.955985      -0.281359
# 2       -1.703042 -0.530965  -0.297555  0.373706      -0.288654
# 3       -1.703042 -0.530965  -0.297555 -0.376848      -0.288654
# 4       -1.703042 -0.530965  -0.278532  1.572025      -0.274329
# ...           ...       ...        ...       ...            ...
# 6362615  3.510123 -0.530965   0.264665 -0.463288      -0.171108
# 6362616  3.510123 -0.530965  10.153953  0.734180       1.896491
# 6362617  3.510123 -0.530965  10.153953  0.143794       1.896491
# 6362618  3.510123 -0.530965   1.109765  0.987353       0.005581
# 6362619  3.510123 -0.530965   1.109765  0.333127       0.005581
#
#          newbalanceOrig  nameDest  oldbalanceDest  newbalanceDest    isFraud
# 0             -0.237622  1.460702       -0.323814       -0.333411  -0.035951
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x1_train,x1_test,y_train,y_test=train_test_split(x1,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x1_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9999984283204089

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 10 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            float64
#  2   amount          float64
#  3   nameOrig        int32
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        int32
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
# dtypes: float64(6), int32(2), int64(2)
# memory usage: 436.9 MB

# %%
input=np.array([[int(input("Step")),
                float(input("type")),
                float(input("amount")),
                int(input("nameOrig")),
                float(input("OldbalanceOrg")),
                float(input("NewbalanceOrg")),
                int(input("nameDest")),
                float(input("oldbalanceDest")),
                float(input("newbalanceDest")),
                int(input("isFraud"))
                ]])
# Out:
# Step11
# type2
# amount2232322
# nameOrig2
# OldbalanceOrg232
# NewbalanceOrg232
# nameDest2
# oldbalanceDest2
# newbalanceDest2
# isFraud1

# %%
output= rfc.predict(input)
# Out:
# D:\anaconda\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
if output == 0:
    print('No Fraud')
else:
    print("Yes Fraud is done")
# Out:
# No Fraud
